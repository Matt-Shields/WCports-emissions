# %%
import os
import pandas as pd
import numpy as np

from new_functions import get_data, group_activities, calc_emissions, efs

output_file = 'WCports_results_23Mar.xlsx'
scenarios = ['WCports_test_ctv6', 'WCports_test_ctv8', 'WCports_test_sov6']

savedir = 'new/'

## percent of transit time to bin as maneuvering
perc_m = 0.1

strategies = []

for s in scenarios:
    times_df = get_data(s, output_file)
    grouped_df, ports = group_activities(times_df, perc_m)
    emissions_df = calc_emissions(grouped_df, efs, ports)
    #emissions_df.set_index(['Vessel', 'Activity'], drop=True, inplace=True)
    strategies.append(emissions_df)

    filename = s + '_emissions.xlsx'
    savepath = savedir + filename
    emissions_df.to_excel(savepath)

# %%
df_0 = strategies[0]
df_1 = strategies[1]
df_2 = strategies[2]
# Out:
#    Vessel      Activity  CrescentCity_ctv    Diablo_ctv    Ilwaco_ctv  \
# 0     aht  idle at port       3537.566903   3140.551634   3350.932398
# 1     aht  idle at site        839.095667    575.252819    639.799431
# 2     aht   maneuvering        122.767224    314.156827    248.607200
# 3     aht       transit       1104.905014   2827.411441   2237.464797
# 4     clv  idle at port        861.918011    750.386357   1047.652588
# 5     clv  idle at site       1430.982708   1421.671722   1662.804375
# 6     clv   maneuvering         98.398654     91.944141    133.525341
# 7     clv       transit        885.587882    827.497270   1201.728073
# 8     ctv  idle at port      22199.020004  22863.617815  21491.358204
# 9     ctv  idle at site      10636.857986  10694.910361  10326.383319
# 10    ctv   maneuvering       1099.412187   1027.147169   1201.225833
# 11    ctv       transit       9894.709681   9244.324522  10811.032501
# 12    dsv  idle at port       1028.679009    981.089971   1019.228379
# 13    dsv  idle at site        591.864625    473.866250    477.588972
# 14    dsv   maneuvering         26.180898     25.252291     31.186694
# 15    dsv       transit        235.628084    227.270619    280.680250
# 16    tug  idle at port         57.308514     65.047542     59.097708
# 17    tug  idle at site        528.765944    267.312319    505.319986
# 18    tug   maneuvering         11.371479     24.045378     20.871246
# 19    tug       transit        102.343311    216.408399    187.841214
#
#     MorroBay_ctv  Westport_ctv  Emissions_factor  \
# 0    2557.441086   2417.751768          1.168779
# 1     477.587000    440.196236          0.584390
# 2     255.637269    177.566241          6.937079
# 3    2300.735423   1598.096170         11.486200
# 4     977.172388   1154.869352          0.444414
# 5    1887.761333   1835.904056          0.222207
# 6     110.688089     95.269460          2.555691
# 7     996.192799    857.425143          4.148690
# 8   23594.485962  24396.269901          0.006957
# 9   10796.972583  10692.850889          0.003479
# 10    943.854137    874.087906          0.432560
# 11   8494.687232   7866.791154          1.111751
# 12    908.814689    939.182936          0.006957
# 13    433.953083    542.315319          0.003479
# 14     23.038938     21.394839          0.432560
# 15    207.350442    192.553547          1.111751
# 16     69.628792     60.157458          1.168779
# 17    271.961972    557.377319          0.584390
# 18     23.136871     20.816572          6.937079
# 19    208.231838    187.349145         11.486200
#
#     CrescentCity_ctv emissions (tons)  Diablo_ctv emissions (tons)  \
# 0                         4134.635181                  3670.611929
# 1                          490.358848                   336.171811
# 2                          851.645891                  2179.330625
# 3                        12691.160324                 32476.214202
# 4                          383.048808                   333.482531
# 5                          317.974688                   315.905720
# 6                          251.476564                   234.980824
# 7                         3674.029300                  3433.029381
# 8                          154.439026                   159.062646
# 9                           37.000417                    37.202353
# 10                         475.561661                   444.302710
# 11                       11000.453699                 10277.387328
# 12                           7.156540                     6.825463
# 13                           2.058807                     1.648348
# 14                          11.324808                    10.923129
# 15                         261.959766                   252.668345
# 16                          66.981008                    76.026224
# 17                         309.005361                   156.214561
# 18                          78.884844                   166.804677
# 19                        1175.535771                  2485.710218
#
#     Ilwaco_ctv emissions (tons)  MorroBay_ctv emissions (tons)  \
# 0                   3916.500623                    2989.084355
# 1                    373.892184                     279.096914
# 2                   1724.607704                    1773.375850
# 3                  25699.968863                   26426.707950
# 4                    465.591936                     434.269517
# 5                    369.487136                     419.474196
# 6                    341.249528                     282.884565
# 7                   4985.596848                    4132.894779
# 8                    149.515809                     164.147311
# 9                     35.920428                      37.557377
# 10                   519.602165                     408.273481
# 11                 12019.176540                    9443.977296
# 12                     7.090792                       6.322642
# 13                     1.661298                       1.509510
# 14                    13.490114                       9.965721
# 15                   312.046558                     230.522068
# 16                    69.072182                      81.380695
# 17                   295.303785                     158.931770
# 18                   144.785476                     160.502294
# 19                  2157.581818                    2391.792607
#
#     Westport_ctv emissions (tons)
# 0                     2825.818364
# 1                      257.246138
# 2                     1231.790985
# 3                    18356.052736
# 4                      513.240614
# 5                      407.951135
# 6                      243.479313
# 7                     3557.190837
# 8                      169.725338
# 9                       37.195189
# 10                     378.095405
# 11                    8745.913184
# 12                       6.533914
# 13                       1.886449
# 14                       9.254550
# 15                     214.071604
# 16                      70.310796
# 17                     325.725553
# 18                     144.406195
# 19                    2151.929808

# %%
activities = ['idle at port', 'idle at site', 'maneuvering', 'transit']
adjusted = []

for df in strategies:
    if 'ctv' in df.values:
        df_copy = pd.DataFrame().reindex_like(df.head(4))
        df_copy['Vessel'] = df_copy['Vessel'].fillna('sov')
        df_copy['Activity'] = activities
    elif 'sov' in df.values:
        df_copy = pd.DataFrame().reindex_like(df.head(4))
        df_copy['Vessel'] = df_copy['Vessel'].fillna('ctv')
        df_copy['Activity'] = activities
    df = pd.concat([df, df_copy], axis=0)
    df.set_index(['Vessel', 'Activity'], drop=True, inplace=True)
    df.fillna(0, inplace=True)
    df.sort_index(ascending=True, inplace=True)
    adjusted.append(df)

# %%
adjusted[0]

## up next, figure out how to join all dataframes together and make sure they stay in the right order
## then, maybe that can just be the output file and then you can create a template in teams.
# Out:
#                          Humboldt     Brookings     Reedsport    RogueRiver  \
# Vessel Activity
# aht    idle at port   3144.485341   2098.751408   2227.863539   2431.821919
#        idle at site    740.426778    173.911319    528.729417    205.358347
#        maneuvering     109.066225    310.161986     86.129852    359.005888
#        transit         981.596022   2791.457872    775.168669   3231.052990
# clv    idle at port   1027.045497   1079.194331   1090.998371   1068.585216
#        idle at site   1796.540472   1879.439597   1859.239333   1873.788056
#        maneuvering      52.238340     57.826930     66.097603     52.848342
#        transit         470.145058    520.442372    594.878429    475.635080
# ctv    idle at port  27160.781866  26440.680262  26433.990875  27004.336013
#        idle at site  11206.412139  11140.091875  10477.119306  11159.779556
#        maneuvering     546.280588    624.922773    691.888969    566.588429
#        transit        4916.525295   5624.304953   6227.000722   5099.295858
# dsv    idle at port    983.554199    923.051039    933.986682    806.289836
#        idle at site    442.173653    409.439542    416.621792    404.674639
#        maneuvering      11.460943     13.173004     13.965948     10.931594
#        transit         103.148484    118.557033    125.693530     98.384342
# sov    idle at port      0.000000      0.000000      0.000000      0.000000
#        idle at site      0.000000      0.000000      0.000000      0.000000
#        maneuvering       0.000000      0.000000      0.000000      0.000000
#        transit           0.000000      0.000000      0.000000      0.000000
# tug    idle at port     49.031083    123.482597     28.454833    111.285292
#        idle at site    408.193000    426.505750    334.725653    422.986556
#        maneuvering       8.638011     33.992276     10.118144     33.138747
#        transit          77.742096    305.930487     91.063296    298.248724
#
#                        Humboldt 2  Emissions_factor  \
# Vessel Activity
# aht    idle at port   3144.485341          1.168779
#        idle at site    740.426778          0.584390
#        maneuvering     109.066225          6.937079
#        transit         981.596022         11.486200
# clv    idle at port   1027.045497          0.444414
#        idle at site   1796.540472          0.222207
#        maneuvering      52.238340          2.555691
#        transit         470.145058          4.148690
# ctv    idle at port  27160.781866          0.006957
#        idle at site  11206.412139          0.003479
#        maneuvering     546.280588          0.432560
#        transit        4916.525295          1.111751
# dsv    idle at port    983.554199          0.006957
#        idle at site    442.173653          0.003479
#        maneuvering      11.460943          0.432560
#        transit         103.148484          1.111751
# sov    idle at port      0.000000          0.000000
#        idle at site      0.000000          0.000000
#        maneuvering       0.000000          0.000000
#        transit           0.000000          0.000000
# tug    idle at port     49.031083          1.168779
#        idle at site    408.193000          0.584390
#        maneuvering       8.638011          6.937079
#        transit          77.742096         11.486200
#
#                      Humboldt emissions (tons)  Brookings emissions (tons)  \
# Vessel Activity
# aht    idle at port                3675.209564                 2452.977327
#        idle at site                 432.697768                  101.631980
#        maneuvering                  756.600982                 2151.618099
#        transit                    11274.808541                32063.244304
# clv    idle at port                 456.433847                  479.609542
#        idle at site                 399.204262                  417.625046
#        maneuvering                  133.505061                  147.787772
#        transit                     1950.485948                 2159.153897
# ctv    idle at port                 188.958103                  183.948341
#        idle at site                  38.981617                   38.750921
#        maneuvering                  236.299094                  270.316552
#        transit                     5465.952070                 6252.826836
# dsv    idle at port                   6.842606                    6.421685
#        idle at site                   1.538105                    1.424240
#        maneuvering                    4.957545                    5.698114
#        transit                      114.675433                  131.805904
# sov    idle at port                   0.000000                    0.000000
#        idle at site                   0.000000                    0.000000
#        maneuvering                    0.000000                    0.000000
#        transit                        0.000000                    0.000000
# tug    idle at port                  57.306518                  144.323911
#        idle at site                 238.543777                  249.245559
#        maneuvering                   59.922559                  235.807095
#        transit                      892.961284                 3513.978857
#
#                      Reedsport emissions (tons)  RogueRiver emissions (tons)  \
# Vessel Activity
# aht    idle at port                 2603.880921                  2842.263266
#        idle at site                  308.984015                   120.009299
#        maneuvering                   597.489561                  2490.452090
#        transit                      8903.742615                 37112.521890
# clv    idle at port                  484.855428                   474.894698
#        idle at site                  413.136402                   416.369233
#        maneuvering                   168.925057                   135.064039
#        transit                      2467.965995                  1973.262345
# ctv    idle at port                  183.901803                   187.869706
#        idle at site                   36.444764                    38.819405
#        maneuvering                   299.283445                   245.083452
#        transit                      6922.874478                  5669.147432
# dsv    idle at port                    6.497764                     5.609375
#        idle at site                    1.449223                     1.407665
#        maneuvering                     6.041109                     4.728569
#        transit                       139.739912                   109.378894
# sov    idle at port                    0.000000                     0.000000
#        idle at site                    0.000000                     0.000000
#        maneuvering                     0.000000                     0.000000
#        transit                         0.000000                     0.000000
# tug    idle at port                   33.257422                   130.067952
#        idle at site                  195.610217                   247.188978
#        maneuvering                    70.190361                   229.886096
#        transit                      1045.971255                  3425.744586
#
#                      Humboldt 2 emissions (tons)
# Vessel Activity
# aht    idle at port                  3675.209564
#        idle at site                   432.697768
#        maneuvering                    756.600982
#        transit                      11274.808541
# clv    idle at port                   456.433847
#        idle at site                   399.204262
#        maneuvering                    133.505061
#        transit                       1950.485948
# ctv    idle at port                   188.958103
#        idle at site                    38.981617
#        maneuvering                    236.299094
#        transit                       5465.952070
# dsv    idle at port                     6.842606
#        idle at site                     1.538105
#        maneuvering                      4.957545
#        transit                        114.675433
# sov    idle at port                     0.000000
#        idle at site                     0.000000
#        maneuvering                      0.000000
#        transit                          0.000000
# tug    idle at port                    57.306518
#        idle at site                   238.543777
#        maneuvering                     59.922559
#        transit                        892.961284
